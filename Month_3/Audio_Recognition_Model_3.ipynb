# %% [markdown]
# ### Audio Recognition for Speech Commands dataset

# %% [markdown]
# #### 1.1 Importing the Speech Commands dataset

# %%
import os
import pathlib
import tensorflow as tf

DATASET_PATH = 'data/mini_speech_commands'
data_dir = pathlib.Path(DATASET_PATH)

#Extracting mini_speech_commands dataset if it is unavailable

if not data_dir.exists() :
  tf.keras.utils.get_file(
    fname='mini_speech_commands.zip',
    origin='http://storage.googleapis.com/download.tensorflow.org/data/mini_speech_commands.zip',
    extract=True,
    cache_dir='.',
    cache_subdir='data'
  )

# %%
#Getting the different commands in the dataset
commands = [x for x in os.listdir(DATASET_PATH) if x != 'README.md']
print(f"Commands : {commands}")
# Out:
# Commands : ['left', 'go', 'up', 'stop', 'yes', 'no', 'right', 'down']

# %%
import numpy as np

seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)

# %%
train_ds, val_ds = tf.keras.utils.audio_dataset_from_directory(
    directory=data_dir,
    batch_size=64,
    validation_split=0.2,
    seed=0,
    output_sequence_length=16000,
    subset="both"
)

labels = np.array(train_ds.class_names)
print('----------------------------------------------')
print(f'Labels : {labels}')
# Out:
# Found 8000 files belonging to 8 classes.
# Using 6400 files for training.
# Using 1600 files for validation.
# ----------------------------------------------
# Labels : ['down' 'go' 'left' 'no' 'right' 'stop' 'up' 'yes']

# %% [markdown]
# ### 1.2 Preprocess the data

# %%
train_ds.element_spec
# Out:
# (TensorSpec(shape=(None, 16000, None), dtype=tf.float32, name=None),
#  TensorSpec(shape=(None,), dtype=tf.int32, name=None))

# %%
# Squeezing the extra dimension of channels as there is only one

def squeeze(audio, labels) :
  audio = tf.squeeze(audio, axis=-1)
  return audio, labels

train_ds = train_ds.map(squeeze, tf.data.AUTOTUNE)
val_ds = val_ds.map(squeeze, tf.data.AUTOTUNE)

# %%
train_ds.element_spec
# Out:
# (TensorSpec(shape=(None, 16000), dtype=tf.float32, name=None),
#  TensorSpec(shape=(None,), dtype=tf.int32, name=None))

# %%
#Splitting the validation set into validation and test sets

test_ds = val_ds.shard(num_shards=2, index=0)
val_ds = val_ds.shard(num_shards=2, index=1)

# %%
for sample_audio, sample_labels in train_ds.take(1) :
  print(f"Audio Shape : {sample_audio.shape}")
  print(f"Label Shape : {sample_labels.shape}")
# Out:
# Audio Shape : (64, 16000)
# Label Shape : (64,)

# %% [markdown]
# ### 1.3 Plotting the audio waveforms

# %%
labels[[1, 0, 3, 1]]
# Out:
# array(['go', 'down', 'no', 'go'], dtype='<U5')

# %%
#Creating a plot with 9 audio samples and corresponding labels
import matplotlib.pyplot as plt

plt.figure(figsize=(16, 10))

rows = 3
cols = 3

for i in range(1, rows * cols + 1) :
  plt.subplot(rows, cols, i)
  audio_sample = sample_audio[i]
  audio_label = labels[sample_labels[i]]
  plt.plot(audio_sample)
  plt.title(audio_label)
  plt.yticks(np.arange(-1.2, 1.2, 0.2))
  plt.ylim([-1.1, 1.1])
  plt.tight_layout()

# %% [markdown]
# ### 1.4 Converting the audio data waveforms into spectrograms

# %%
def get_spectrogram(waveform) :
  # 1. Waveform to Spectrogram using Short-time Fourier Transform
  spectrogram = tf.signal.stft(waveform,
                              frame_length=255,
                              frame_step=128)

  # 2. Getting the magnitude of Spectrogram
  spectrogram = tf.abs(spectrogram)

  # 3. Adding a new axis to make it look like (batch, samples, channels) form of an image
  spectrogram = spectrogram[..., tf.newaxis]
  return spectrogram

# %%
from IPython import display

for i in range(3) :
  label = sample_labels[i]
  waveform = sample_audio[i]
  spectrogram = get_spectrogram(waveform)

  print(f"Label            : {labels[label]}")
  print(f"Waveform Shape   : {waveform.shape}")
  print(f"Spectrogram Shape : {spectrogram.shape}")
  display.display(display.Audio(waveform, rate=16000))
# Out:
# Label            : go
# Waveform Shape   : (16000,)
# Spectrogram Shape : (124, 129, 1)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Label            : no
# Waveform Shape   : (16000,)
# Spectrogram Shape : (124, 129, 1)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Label            : left
# Waveform Shape   : (16000,)
# Spectrogram Shape : (124, 129, 1)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Plotting the spectrogram

def plot_spectrogram(spectrogram, ax) :

  # 1. Check if length of spectrogram.shape == 3 else raise an AssertionError and squezze the extra dim
  if(len(spectrogram.shape) > 2) :
    assert len(spectrogram.shape) == 3
    spectrogram = np.squeeze(spectrogram, axis=-1)

  # 2. Do a logarithmic transformation on the spectrogram and add a epsilon to avoid taking log(0)
  log_spec = np.log(spectrogram + np.finfo(float).eps)
  height, width = log_spec.shape[0], log_spec.shape[1]

  # 3. Set X and Y for the colormesh
  X = np.linspace(0, np.size(spectrogram), num=width, dtype=int)
  Y = range(height)
  ax.pcolormesh(X, Y, log_spec)

# %%
# Plotting the waveform and spectrogram

fig, axes = plt.subplots(2, figsize=(12, 6))
timescale = np.arange(waveform.shape[0])
axes[0].plot(timescale, waveform.numpy())
axes[0].set_title('Waveform')
axes[0].set_xlim(0, 16000)

plot_spectrogram(spectrogram, axes[1])
axes[1].set_title('Spectrogram')
plt.suptitle(labels[label].title())
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1.5 Create Spectrogram datasets from waveform data

# %%
def make_spec_ds(ds) :
  return ds.map(
      map_func = lambda audio, label : (get_spectrogram(audio), label),
      num_parallel_calls = tf.data.AUTOTUNE
  )

train_spectrogram_ds = make_spec_ds(train_ds)
val_spectrogram_ds = make_spec_ds(val_ds)
test_spectrogram_ds = make_spec_ds(test_ds)

# %%
# Plotting the spectrograms

for sample_spect, sample_spect_labels in train_spectrogram_ds.take(1) :
  break

rows = 3
cols = 3
n = rows * cols
fig, axes = plt.subplots(rows, cols, figsize=(16, 9))

for i in range(n) :
  r = i // cols
  c = i % cols
  ax = axes[r][c]
  plot_spectrogram(sample_spect[i].numpy(), ax)
  ax.set_title(labels[sample_spect_labels[i].numpy()])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2.1 Build and Train the model

# %%
# Add cache and prefetch to reduce latency

train_spectrogram_ds = train_spectrogram_ds.cache().shuffle(1000).prefetch(tf.data.AUTOTUNE)
val_spectrogram_ds = val_spectrogram_ds.cache().prefetch(tf.data.AUTOTUNE)
test_spectrogram_ds = test_spectrogram_ds.cache().prefetch(tf.data.AUTOTUNE)

# %%
# Building a Convolutional Model as audio data is transformed to spectrogram images

input_shape = sample_spect.shape[1:]
print(f"Input Shape : {input_shape}")
num_labels = len(labels)
print(f"Output Units : {num_labels}")
# Out:
# Input Shape : (124, 129, 1)
# Output Units : 8

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

model_1 = models.Sequential([
    layers.Input(shape=input_shape[:2]),
    layers.Normalization(axis=-1),
    layers.LSTM(64, return_sequences=True),
    layers.LSTM(64),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(num_labels, activation='softmax')
])

model_1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization_1 (Normaliza  (None, 124, 129)          259
#  tion)
#
#  lstm_2 (LSTM)               (None, 124, 64)           49664
#
#  lstm_3 (LSTM)               (None, 64)                33024
#
#  dense_2 (Dense)             (None, 128)               8320
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 8)                 1032
#
# =================================================================
# Total params: 92299 (360.55 KB)
# Trainable params: 92040 (359.53 KB)
# Non-trainable params: 259 (1.02 KB)
# _________________________________________________________________

# %%
# Configuring the model Adam Optimizer and SparseCategoricalCrossentropy

model_1.compile(
    optimizer = tf.keras.optimizers.Adam(),
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics = ['accuracy'],
)

# %%
# Training the model for 10 epochs

EPOCHS = 10

history = model_1.fit(
    train_spectrogram_ds,
    validation_data = val_spectrogram_ds,
    epochs = EPOCHS
)
# Out:
# Epoch 1/10
# 100/100 [==============================] - 28s 279ms/step - loss: 1.5413 - accuracy: 0.3906 - val_loss: 1.5516 - val_accuracy: 0.4036
# Epoch 2/10
# 100/100 [==============================] - 23s 233ms/step - loss: 1.3555 - accuracy: 0.4945 - val_loss: 1.1936 - val_accuracy: 0.5781
# Epoch 3/10
# 100/100 [==============================] - 23s 226ms/step - loss: 1.1427 - accuracy: 0.5863 - val_loss: 1.1614 - val_accuracy: 0.5768
# Epoch 4/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.1176 - accuracy: 0.5919 - val_loss: 1.1233 - val_accuracy: 0.5820
# Epoch 5/10
# 100/100 [==============================] - 24s 237ms/step - loss: 1.0151 - accuracy: 0.6250 - val_loss: 1.1341 - val_accuracy: 0.5820
# Epoch 6/10
# 100/100 [==============================] - 23s 231ms/step - loss: 0.9783 - accuracy: 0.6506 - val_loss: 1.1337 - val_accuracy: 0.5664
# Epoch 7/10
# 100/100 [==============================] - 23s 232ms/step - loss: 1.1244 - accuracy: 0.5831 - val_loss: 1.1993 - val_accuracy: 0.5495
# Epoch 8/10
# 100/100 [==============================] - 23s 230ms/step - loss: 0.9972 - accuracy: 0.6389 - val_loss: 1.1463 - val_accuracy: 0.5677
# Epoch 9/10
# 100/100 [==============================] - 23s 232ms/step - loss: 0.9055 - accuracy: 0.6725 - val_loss: 0.8865 - val_accuracy: 0.6758
# Epoch 10/10
# 100/100 [==============================] - 23s 227ms/step - loss: 0.7961 - accuracy: 0.7064 - val_loss: 0.8830 - val_accuracy: 0.6901

# %%
#Plotting the Loss and Accuracy Curves

metrics = history.history

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(history.epoch, metrics['loss'], metrics['val_loss'])
plt.ylim(0, max(plt.ylim()))
plt.legend(['loss', 'val_loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss [CrossEntropy]')

plt.subplot(1, 2, 2)
plt.plot(history.epoch, 100 * np.array(metrics['accuracy']), 100 * np.array(metrics['val_accuracy']))
plt.legend(['accuracy', 'val_accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy [%]')

plt.show()

# %% [markdown]
# ### 3.1 Evaluate the model performance

# %%
model_1.evaluate(test_spectrogram_ds, return_dict=True)
# Out:
# 13/13 [==============================] - 4s 307ms/step - loss: 0.7702 - accuracy: 0.6959
# {'loss': 0.7702330946922302, 'accuracy': 0.6959134340286255}

# %% [markdown]
# ### 3.2 Display a Confusion Matrix

# %%
y_pred = tf.argmax(model_1.predict(test_spectrogram_ds), axis=1)
y_true = tf.concat(list(test_spectrogram_ds.map(lambda spec, label : label)), axis=0)
# Out:
# 13/13 [==============================] - 6s 179ms/step

# %%
import seaborn as sns

conf_mat = tf.math.confusion_matrix(y_true, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(conf_mat,
            xticklabels=labels,
            yticklabels=labels,
            annot=True,
            fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()

# %% [markdown]
# ### 3.3 Run inference on random audio file

# %%
x = data_dir/'go/004ae714_nohash_0.wav'
x = tf.io.read_file(str(x))
x, sample_rate = tf.audio.decode_wav(x, desired_channels=1, desired_samples=16000)
x = tf.squeeze(x, axis=-1)
waveform = x
x = get_spectrogram(x)
x = x[tf.newaxis, ...]

pred = model_1(x)
plt.bar(labels, tf.nn.softmax(pred[0]))
plt.title('Go')
plt.show()

display.display(display.Audio(waveform, rate=16000))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### 4. Export the model with preprocessing steps

# %%
class ExportModel(tf.Module) :
  def __init__(self, model) :

    self.model = model
    self.__call__.get_concrete_function(
        x=tf.TensorSpec(shape=(), dtype=tf.string),
    )
    self.__call__.get_concrete_function(
        x=tf.TensorSpec(shape=[None, 16000], dtype=tf.float32)
    )

  @tf.function
  def __call__(self, x) :
    if x.dtype == tf.string :
      x = tf.io.read_file(x)
      x, _ = tf.audio.decode_wav(x, desired_channels=1, desired_samples=16000, )
      x = tf.squeeze(x, axis=-1)
      x = x[tf.newaxis, ...]

    x = get_spectrogram(x)
    result = self.model(x, training=False)

    class_ids = tf.argmax(result, axis=-1)
    class_names = tf.gather(labels, class_ids)
    return {
        'predictions' : result,
        'class_ids' : class_ids,
        'class_names' : class_names
    }

# %%
# Test run the export model

export = ExportModel(model_1)
export(tf.constant(str(data_dir/'no/01bb6a2a_nohash_0.wav')))
# Out:
# {'predictions': <tf.Tensor: shape=(1, 8), dtype=float32, numpy=
#  array([[0.03794911, 0.45295334, 0.00275059, 0.49563086, 0.00247443,
#          0.00267617, 0.0045179 , 0.00104749]], dtype=float32)>,
#  'class_ids': <tf.Tensor: shape=(1,), dtype=int64, numpy=array([3])>,
#  'class_names': <tf.Tensor: shape=(1,), dtype=string, numpy=array([b'no'], dtype=object)>}

# %%
# Save and reload the model

tf.saved_model.save(export, 'saved')
reloaded_model = tf.saved_model.load('saved')

# %%
print(reloaded_model(waveform[tf.newaxis, :]))
# Out:
# {'class_names': <tf.Tensor: shape=(1,), dtype=string, numpy=array([b'up'], dtype=object)>, 'class_ids': <tf.Tensor: shape=(1,), dtype=int64, numpy=array([6])>, 'predictions': <tf.Tensor: shape=(1, 8), dtype=float32, numpy=
# array([[0.10257701, 0.1436671 , 0.14701803, 0.17113306, 0.06972332,
#         0.07402278, 0.20668687, 0.08517187]], dtype=float32)>}
